# %%
print("Hello world")
# Out:
# Hello world

# %%
zahlen = 7
print(zahlen)
print(type(zahlen))
print(float(zahlen))
# Out:
# 7
# <class 'int'>
# 7.0

# %%
str1 = "Hallo"
str2 = "Welt"
print(str1 + " "+ str2)
str1 * 3
len(str2)
# Out:
# Hallo Welt
# 4

# %%
text = f"Hallo {str2}"
print(text)
# Out:
# Hallo Welt
